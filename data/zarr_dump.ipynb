# %%
import xarray as xr
# %matplotlib inline

time_range_data = xr.open_zarr('20210623_1100-1200_limrad94-CLOUDNETpy94-2D.zarr', decode_times=False)
ann_input_data = xr.open_zarr('20210623_1100-1200_limrad94-CLOUDNETpy94-ND.zarr', decode_times=False)

# %%
time_range_data
# Out:
# <xarray.Dataset>
# Dimensions:           (dt: 120, rg: 292, ts: 120)
# Coordinates:
#   * dt                (dt) int64 0 29999542 59999085 ... 3540000916 3570000458
#   * rg                (rg) float32 119.247086 149.05884 ... 11924.608 11964.357
#   * ts                (ts) float64 1.624e+09 1.624e+09 ... 1.624e+09 1.624e+09
# Data variables:
#     CLASS             (ts, rg) int32 dask.array<shape=(120, 292), chunksize=(120, 292)>
#     LWP               (ts) float32 dask.array<shape=(120,), chunksize=(120,)>
#     P                 (ts, rg) float64 dask.array<shape=(120, 292), chunksize=(60, 292)>
#     T                 (ts, rg) float64 dask.array<shape=(120, 292), chunksize=(60, 292)>
#     Tw                (ts, rg) float32 dask.array<shape=(120, 292), chunksize=(120, 292)>
#     UWIND             (ts, rg) float64 dask.array<shape=(120, 292), chunksize=(60, 292)>
#     VEL               (ts, rg) float32 dask.array<shape=(120, 292), chunksize=(120, 292)>
# ...

# %%
ann_input_data
# Out:
# <xarray.Dataset>
# Dimensions:       (dt: 120, nbits: 6, nchannels: 6, npol: 2, nsamples: 11860, nvelocity: 256, rg: 292, ts: 120)
# Coordinates:
#   * dt            (dt) int64 0 29999542 59999085 ... 3540000916 3570000458
#   * nbits         (nbits) int64 0 1 2 3 4 5
#   * nchannels     (nchannels) int64 0 1 2 3 4 5
#   * npol          (npol) int64 0 1
#   * nsamples      (nsamples) int64 0 1 2 3 4 5 ... 11855 11856 11857 11858 11859
#   * nvelocity     (nvelocity) int64 0 1 2 3 4 5 6 ... 250 251 252 253 254 255
#   * rg            (rg) float32 119.247086 149.05884 ... 11924.608 11964.357
#   * ts            (ts) float64 1.624e+09 1.624e+09 ... 1.624e+09 1.624e+09
# Data variables:
#     features      (nsamples, nvelocity, nchannels, npol) float32 dask.array<shape=(11860, 256, 6, 2), chunksize=(2965, 64, 2, 1)>
#     masked        (ts, rg) bool dask.array<shape=(120, 292), chunksize=(120, 292)>
# ...

# %%
time_range_data['Z'].T.plot()
